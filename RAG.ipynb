# %%
# !pip install llama-index chromadb llama-index-embeddings-huggingface litellm
# Out:
# ...
# WARNING: huggingface-hub 1.10.1 does not provide the extra 'inference'
# ...

# %%
# !pip install llama-index-vector-stores-chroma

# %%
# !pip install llama-index-llms-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 121.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 57.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.10.1
#     Uninstalling huggingface_hub-1.10.1:
#       Successfully uninstalled huggingface_hub-1.10.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: llama-index-llms-openai
#     Found existing installation: llama-index-llms-openai 0.7.5
#     Uninstalling llama-index-llms-openai-0.7.5:
#       Successfully uninstalled llama-index-llms-openai-0.7.5
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0a1eeb26-7aee-4b1e-802c-fd0c5b5e7f44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a1eeb26-7aee-4b1e-802c-fd0c5b5e7f44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs('./data/', exist_ok=True)
# !mv 'Heap_Notes.pdf' ./data/
# Out:
# mv: cannot stat 'Heap_Notes.pdf': No such file or directory

# %%
from llama_index.core import SimpleDirectoryReader, StorageContext, VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from litellm import completion
import chromadb

# %%
## llama-index GROQ
import os
from llama_index.llms.groq import Groq
from google.colab import userdata
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
llm = Groq(model="lama-3.3-70b-versatile", api_key=GROQ_API_KEY)
llm
# Out:
# Groq(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7f47a47c1430>, rate_limiter=None, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x7f49963ace00>, completion_to_prompt=<function default_completion_to_prompt at 0x7f49960e7ba0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='lama-3.3-70b-versatile', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.groq.com/openai/v1', api_version='', strict=False, reasoning_effort=None, modalities=None, audio_config=None, context_window=3900, is_chat_model=True, is_function_calling_model=True, should_use_structured_outputs=False, tokenizer=None)

# %%
# !pip install llama-index-llms-litellm

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.litellm import LiteLLM
from llama_index.core.llms import ChatMessage
from llama_index.embeddings.huggingface import HuggingFaceEmbedding  # Add this import

# 1. Configure Embedding Model (Local Hugging Face)
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# 2. Configure LLM (Groq LLAMA)
llm = LiteLLM("groq/llama-3.3-70b-versatile")

# 3. Load data with local embeddings
data = SimpleDirectoryReader(input_dir="./data/").load_data()
index = VectorStoreIndex.from_documents(
    data,
    embed_model=embed_model  # Critical: Use local embeddings
)

# 4. Create query engine with Groq LLM
query_engine = index.as_query_engine(llm=llm)  # Now works

# 5. Querying: Retrieve relevant chunks and generate response
response = query_engine.query("What is the main finding of the PDF?")
print(response)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# ...

# %%
chat_engine = index.as_chat_engine(chat_mode="best", llm=llm, verbose=True)
chat_engine

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core import Settings

llm = LiteLLM("groq/llama-3.3-70b-versatile", temperature=0.7)
Settings.llm = llm
data = SimpleDirectoryReader(input_dir="./data/").load_data()
index = VectorStoreIndex.from_documents(data, settings=Settings,embed_model=embed_model )
query_engine = index.as_query_engine()
response = query_engine.query("What is min heap.explain in example?")
print(response)
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# A min heap is a complete binary tree where each node is smaller than its children. This means that the root node is the smallest element in the tree.
#
# For example, consider the following min heap:
#
#         5
#        / \
#       7   10
#      / \   /
#     12 15 20
#
# In this example, the root node (5) is the smallest element. The left child (7) and right child (10) are both larger than the root. Similarly, the grandchildren (12, 15, and 20) are larger than their parents.
#
# The properties of a min heap are:
#
# 1. The tree is a complete binary tree, meaning all levels are fully filled except the last level, which is filled from left to right.
# 2. The parent node is smaller than its children.
#
# ...

# %%
chat_engine = index.as_chat_engine(
    chat_mode="condense_plus_context",
    context_prompt=(
        "You are a chatbot, able to have normal interactions, as well as talk"
        " about an essay Factional Investment and its Benefits."
        "Here are the relevant documents for the context:\n"
        "{context_str}"
        "\nInstruction: Based on the above documents, provide a detailed answer for the user question below."
    ),
)

# %%
response = chat_engine.stream_chat("what is max heap.explain with example?")
for token in response.response_gen:
    print(token, end="")
# Out:
# tokenizer.json: 0.00B [00:00, ?B/s]
# A max heap is a complete binary tree where each parent node is greater than or equal to its child nodes. In other words, the parent node has the maximum value among all its child nodes. This property is known as the "max heap property."
#
# Here's an example to illustrate this:
#
# Suppose we have the following max heap:
#
#         10
#        /  \
#       8    9
#      / \   / \
#     5   6 4   7
#    / \   / \
#   2   3 1   0
#
# In this example, the root node (10) is the maximum value in the heap. The left child of the root node (8) is less than the root node, and the right child of the root node (9) is also less than the root node. Similarly, the child nodes of the left child node (5 and 6) are less than the left child node, and the child nodes of the right child node (4 and 7) are less than the right child node.
#
# To demonstrate the max heap property, let's consider a few examples:
#
# ...
